# %%
"""
Created on Mon Jun  7 23:07:17 2021

@author: User
"""

import turtle
import random
import math

odd_number_as_sqrt_of_population = 15

infection_prob = 100
population = odd_number_as_sqrt_of_population**2
recovery_time = 100
social_distancing = False
start_sd = 30
sd_p = 100
quarantaine_on = True
time_until_q = 3000

wn = turtle.Screen()
wn.bgcolor('black')
wn.title('Epidemic simulator')
wn.tracer(0)

pen = turtle.Turtle()
pen.speed(0)
pen.color('white')
pen.penup()
pen.setposition(-200,-200)
pen.pendown()
pen.pensize(3)
for i in range(4):
    pen.fd(400)
    pen.lt(90)
pen.hideturtle()

time = 0
balls = []
infected = []
time_infected = {}
tot_inf = []
recovered = []
closest_ball = []
spaces_x = []
spaces_y = []
coordinates = []

for i in range(-200,201):
    if i%int(400/math.sqrt(population)) == 0:
        spaces_x.append(i)
        spaces_y.append(i)

for x in spaces_x:
    for y in spaces_y:
        coordinate = [x,y]
        coordinates.append(coordinate)

for _ in range(population):
    balls.append(turtle.Turtle())
for ball in balls:
    ball.shape('circle')
    ball.shapesize(0.45,0.45)
    ball.color('#4183C4')
    ball.penup()
    ball.speed(0)
    x = random.randint(-190, 190)
    y = random.randint(-190, 190)
    ball.goto(x, y)
    ball.dx = random.choice([-3,-2.75,-2.5,-2.25,-2,-1.75,-1.5,-1.25,-1,-0.75,-0.5,-0.25,3,2.75,2.5,2.25,2,1.75,1.5,1.25,1,0.75,0.5,0.25])
    ball.dy = random.choice([-3,-2.75,-2.5,-2.25,-2,-1.75,-1.5,-1.25,-1,-0.75,-0.5,-0.25,3,2.75,2.5,2.25,2,1.75,1.5,1.25,1,0.75,0.5,0.25])
    
infections = {i : 0 for i in balls}

def closest_to_O():
    global closest_ball

    min_dist = 0
    for x in range(len(balls)):

            xdist = balls[x].xcor()
            ydist = balls[x].ycor()
            dist_squared = xdist*xdist + ydist*ydist
            if len(closest_ball) == 0:
                closest_ball.append(balls[x])
                min_dist = dist_squared
            elif dist_squared < min_dist:
                closest_ball.clear()
                closest_ball.append(balls[x])
                min_dist = dist_squared
def mark_infected():
    global closest_ball
    
    if closest_ball[0] not in recovered:
        closest_ball[0].color('red')
        infected.append(closest_ball[0])
def collide():
    global infection_prob

    for i in range(len(balls)):

        for x in range(i+1, len(balls)):

            xdist = balls[i].xcor() - balls[x].xcor()
            ydist = balls[i].ycor() - balls[x].ycor()
            dist_squared = xdist*xdist + ydist*ydist
            if dist_squared < 125:
                if balls[i] not in recovered and balls[x] not in recovered:
                    if balls[i] in infected and balls[x] not in infected and random.randint(0,100) in range(0, infection_prob + 1):
                        balls[x].color('red') 
                        infected.append(balls[x])
                    elif balls[i] not in infected and balls[x] in infected and random.randint(0,100) in range(0, infection_prob + 1):
                        balls[i].color('red')
                        infected.append(balls[i])
def recovered_():

    global population, recovery_time

    for i in range(len(balls)):
        if balls[i] in infected:
            infections[balls[i]] += 1
            if balls[i] not in recovered:
                if infections[balls[i]] >= recovery_time:
                    balls[i].color('gray')
                    recovered.append(balls[i])
                    
def social_dist():

    min_dist = 0
    closest_dist = []

    for i in range(len(balls)):

        if balls[i].xcor() > -250:
            
            if random.randint(0,100) in range(0, sd_p + 1):

                for c in coordinates:

                    xdist = balls[i].xcor() - c[0]
                    ydist = balls[i].ycor() - c[1]
                    dist_squared = xdist*xdist + ydist*ydist
                    if len(closest_dist) == 0:
                        closest_dist = c
                        min_dist = dist_squared
                    elif dist_squared < min_dist:
                        closest_dist = c
                        min_dist = dist_squared
                        
                if len(coordinates) > 0:
                    try:
                        coordinates.remove(closest_dist)
                    except:
                        coordinates.remove(coordinates[0])
                    balls[i].dx = 0
                    balls[i].dy = 0
                    balls[i].goto(closest_dist[0], closest_dist[1])

                closest_dist.clear()

def quarantaine():
    global time_infected    
    
    
    room = turtle.Turtle()
    room.speed(0)
    room.color('white')
    room.penup()
    room.setposition(-360,-210)
    room.pendown()
    room.pensize(3)
    for i in range(4):
        room.fd(120)
        room.lt(90)
    room.hideturtle()
    
    for i in infected:

        if i.xcor() >= -350 and i.xcor() <= -250 and i.ycor() >= -200 and i.ycor() <= -100:
            i.dx = 0
            i.dy = 0
            i.setposition(random.randint(-350,-250), random.randint(-200,-100))
            time_infected[i] = 0

        elif i not in time_infected.keys():
            time_infected[i] = time
        elif i in time_infected.keys():
            if time - time_infected[i] >= time_until_q and i.xcor() > -250:
                dx_q = (random.randint(-275,-225) - i.xcor())*(-1)
                dy_q = random.randint(-175,-125) - i.ycor()
                try:
                    rc = dy_q/dx_q
                    if -4 < rc < 4:
                        i.dx = -10
                        i.dy = 10 * rc
                    else:
                        i.dx = 0
                        i.dy = 0
                        i.goto(random.randint(-350,-250), random.randint(-200,-100))
                        time_infected[i] = 0
                except:
                    i.dx = 0
                    i.dy = 0
                    i.goto(random.randint(-350,-250), random.randint(-200,-100))
                    time_infected[i] = 0
                time_infected[i] = 0
            
    

closest_to_O()
mark_infected()

while True:
        
    wn.update()
    
    for ball in balls:
        
        time += 1

        ball.sety(ball.ycor() + ball.dy)
        ball.setx(ball.xcor() + ball.dx)
        
        if ball.xcor() < -195 or ball.xcor() > 195:
            ball.dx *= -1
            
        if ball.ycor() < -195 or ball.ycor() > 195:
            ball.dy *= -1
            
    collide()
    recovered_()

    if social_distancing and len(tot_inf) >= start_sd:
        social_dist()

    if quarantaine_on:
        quarantaine()

    for i in infected: 
        if i not in tot_inf: 
            tot_inf.append(i)
        
    if len(recovered) < len(tot_inf):
        print('\n', 'Percentage infected:', len(tot_inf)/population * 100, '\n',
        'Infected people:' , len(tot_inf), '\n' , 'Recovered people:', len(recovered), '\n', 'Time:' , time , 'minutes')
        
    if len(recovered) == len(tot_inf) and len(recovered) > 0:
        message = 'Percentage infected: '+str(len(tot_inf)/population * 100)+'\n'+'Infected people: '+str(len(tot_inf))+'\n'+'Recovered people: '+str(len(recovered))+'\n'+'Time: '+str(time)+' minutes'
        end_message = turtle.Turtle()
        end_message.speed(0)
        end_message.color('white')
        end_message.penup()
        end_message.setposition(-190,205)
        end_message.pendown()
        end_message.pensize(10)
        end_message.write(message, font = ('style', 18, 'bold'))
        end_message.hideturtle()
        break
    
wn.mainloop()
# Out:
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 225 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 450 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 675 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 900 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 1125 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 1350 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 1575 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 1800 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 2025 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 2250 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 2475 minutes
#
#  Percentage infected: 0.8888888888888888
#  Infected people: 2
#  Recovered people: 0
#  Time: 2700 minutes
#
#  Percentage infected: 0.8888888888888888
#  Infected people: 2
#  Recovered people: 0
#  Time: 2925 minutes
#
#  Percentage infected: 0.8888888888888888
#  Infected people: 2
#  Recovered people: 0
#  Time: 3150 minutes
#
#  Percentage infected: 0.8888888888888888
#  Infected people: 2
#  Recovered people: 0
#  Time: 3375 minutes
#
#  Percentage infected: 0.8888888888888888
#  Infected people: 2
#  Recovered people: 0
#  Time: 3600 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 3825 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 4050 minutes
#
#  Percentage infected: 1.7777777777777777
#  Infected people: 4
#  Recovered people: 0
#  Time: 4275 minutes
#
#  Percentage infected: 2.2222222222222223
#  Infected people: 5
#  Recovered people: 0
#  Time: 4500 minutes
#
#  Percentage infected: 2.666666666666667
#  Infected people: 6
#  Recovered people: 0
#  Time: 4725 minutes
#
#  Percentage infected: 3.111111111111111
#  Infected people: 7
#  Recovered people: 0
#  Time: 4950 minutes
#
#  Percentage infected: 4.0
#  Infected people: 9
#  Recovered people: 0
#  Time: 5175 minutes
#
#  Percentage infected: 4.444444444444445
#  Infected people: 10
#  Recovered people: 0
#  Time: 5400 minutes
#
#  Percentage infected: 4.888888888888889
#  Infected people: 11
#  Recovered people: 0
#  Time: 5625 minutes
#
#  Percentage infected: 4.888888888888889
#  Infected people: 11
#  Recovered people: 0
#  Time: 5850 minutes
#
#  Percentage infected: 4.888888888888889
#  Infected people: 11
#  Recovered people: 0
#  Time: 6075 minutes
#
#  Percentage infected: 5.333333333333334
#  Infected people: 12
#  Recovered people: 0
#  Time: 6300 minutes
#
#  Percentage infected: 6.222222222222222
#  Infected people: 14
#  Recovered people: 0
#  Time: 6525 minutes
#
#  Percentage infected: 6.666666666666667
#  Infected people: 15
#  Recovered people: 0
#  Time: 6750 minutes
#
#  Percentage infected: 7.111111111111111
#  Infected people: 16
#  Recovered people: 0
#  Time: 6975 minutes
#
#  Percentage infected: 7.555555555555555
#  Infected people: 17
#  Recovered people: 0
#  Time: 7200 minutes
#
#  Percentage infected: 7.555555555555555
#  Infected people: 17
#  Recovered people: 0
#  Time: 7425 minutes
#
#  Percentage infected: 8.0
#  Infected people: 18
#  Recovered people: 0
#  Time: 7650 minutes
#
#  Percentage infected: 8.444444444444445
#  Infected people: 19
#  Recovered people: 0
#  Time: 7875 minutes
#
#  Percentage infected: 9.777777777777779
#  Infected people: 22
#  Recovered people: 0
#  Time: 8100 minutes
#
#  Percentage infected: 10.222222222222223
#  Infected people: 23
#  Recovered people: 0
#  Time: 8325 minutes
#
#  Percentage infected: 11.11111111111111
#  Infected people: 25
#  Recovered people: 0
#  Time: 8550 minutes
#
#  Percentage infected: 11.11111111111111
#  Infected people: 25
#  Recovered people: 0
#  Time: 8775 minutes
#
#  Percentage infected: 11.555555555555555
#  Infected people: 26
#  Recovered people: 0
#  Time: 9000 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 9225 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 9450 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 9675 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 9900 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 10125 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 10350 minutes
#
#  Percentage infected: 12.88888888888889
#  Infected people: 29
#  Recovered people: 0
#  Time: 10575 minutes
#
#  Percentage infected: 12.88888888888889
#  Infected people: 29
#  Recovered people: 0
#  Time: 10800 minutes
#
#  Percentage infected: 12.88888888888889
#  Infected people: 29
#  Recovered people: 0
#  Time: 11025 minutes
#
#  Percentage infected: 12.88888888888889
#  Infected people: 29
#  Recovered people: 0
#  Time: 11250 minutes
#
#  Percentage infected: 12.88888888888889
#  Infected people: 29
#  Recovered people: 0
#  Time: 11475 minutes
#
#  Percentage infected: 14.222222222222221
#  Infected people: 32
#  Recovered people: 0
#  Time: 11700 minutes
#
#  Percentage infected: 14.222222222222221
#  Infected people: 32
#  Recovered people: 0
#  Time: 11925 minutes
#
#  Percentage infected: 15.11111111111111
#  Infected people: 34
#  Recovered people: 0
#  Time: 12150 minutes
#
#  Percentage infected: 15.11111111111111
#  Infected people: 34
#  Recovered people: 0
#  Time: 12375 minutes
#
#  Percentage infected: 15.11111111111111
#  Infected people: 34
#  Recovered people: 0
#  Time: 12600 minutes
#
#  Percentage infected: 16.0
#  Infected people: 36
#  Recovered people: 0
#  Time: 12825 minutes
#
#  Percentage infected: 16.88888888888889
#  Infected people: 38
#  Recovered people: 0
#  Time: 13050 minutes
#
#  Percentage infected: 17.333333333333336
#  Infected people: 39
#  Recovered people: 0
#  Time: 13275 minutes
#
#  Percentage infected: 17.333333333333336
#  Infected people: 39
#  Recovered people: 0
#  Time: 13500 minutes
#
#  Percentage infected: 18.22222222222222
#  Infected people: 41
#  Recovered people: 0
#  Time: 13725 minutes
#
#  Percentage infected: 18.22222222222222
#  Infected people: 41
#  Recovered people: 0
#  Time: 13950 minutes
#
#  Percentage infected: 18.22222222222222
#  Infected people: 41
#  Recovered people: 0
#  Time: 14175 minutes
#
#  Percentage infected: 18.22222222222222
#  Infected people: 41
#  Recovered people: 0
#  Time: 14400 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 14625 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 14850 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 15075 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 15300 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 15525 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 15750 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 15975 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 16200 minutes
#
#  Percentage infected: 19.555555555555557
#  Infected people: 44
#  Recovered people: 0
#  Time: 16425 minutes
#
#  Percentage infected: 19.555555555555557
#  Infected people: 44
#  Recovered people: 0
#  Time: 16650 minutes
#
#  Percentage infected: 20.0
#  Infected people: 45
#  Recovered people: 0
#  Time: 16875 minutes
#
#  Percentage infected: 20.0
#  Infected people: 45
#  Recovered people: 0
#  Time: 17100 minutes
#
#  Percentage infected: 20.0
#  Infected people: 45
#  Recovered people: 0
#  Time: 17325 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 17550 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 17775 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 18000 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 18225 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 18450 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 18675 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 18900 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 19125 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 19350 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 19575 minutes
#
#  Percentage infected: 20.88888888888889
#  Infected people: 47
#  Recovered people: 0
#  Time: 19800 minutes
#
#  Percentage infected: 20.88888888888889
#  Infected people: 47
#  Recovered people: 0
#  Time: 20025 minutes
#
#  Percentage infected: 20.88888888888889
#  Infected people: 47
#  Recovered people: 0
#  Time: 20250 minutes
#
#  Percentage infected: 20.88888888888889
#  Infected people: 47
#  Recovered people: 0
#  Time: 20475 minutes
#
#  Percentage infected: 20.88888888888889
#  Infected people: 47
#  Recovered people: 0
#  Time: 20700 minutes
#
#  Percentage infected: 20.88888888888889
#  Infected people: 47
#  Recovered people: 0
#  Time: 20925 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 21150 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 21375 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 21600 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 21825 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 22050 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 22275 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 22500 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 22725 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 22950 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 23175 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 23400 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 23625 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 23850 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 24075 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 24300 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 24525 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 1
#  Time: 24750 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 2
#  Time: 24975 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 2
#  Time: 25200 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 2
#  Time: 25425 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 2
#  Time: 25650 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 2
#  Time: 25875 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 3
#  Time: 26100 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 3
#  Time: 26325 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 4
#  Time: 26550 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 5
#  Time: 26775 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 6
#  Time: 27000 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 7
#  Time: 27225 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 9
#  Time: 27450 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 10
#  Time: 27675 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 11
#  Time: 27900 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 11
#  Time: 28125 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 11
#  Time: 28350 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 12
#  Time: 28575 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 14
#  Time: 28800 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 15
#  Time: 29025 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 16
#  Time: 29250 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 17
#  Time: 29475 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 17
#  Time: 29700 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 18
#  Time: 29925 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 19
#  Time: 30150 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 22
#  Time: 30375 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 23
#  Time: 30600 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 25
#  Time: 30825 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 25
#  Time: 31050 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 26
#  Time: 31275 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 28
#  Time: 31500 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 28
#  Time: 31725 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 28
#  Time: 31950 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 28
#  Time: 32175 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 28
#  Time: 32400 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 28
#  Time: 32625 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 29
#  Time: 32850 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 29
#  Time: 33075 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 29
#  Time: 33300 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 29
#  Time: 33525 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 29
#  Time: 33750 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 32
#  Time: 33975 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 32
#  Time: 34200 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 34
#  Time: 34425 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 34
#  Time: 34650 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 34
#  Time: 34875 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 36
#  Time: 35100 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 38
#  Time: 35325 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 39
#  Time: 35550 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 39
#  Time: 35775 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 41
#  Time: 36000 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 41
#  Time: 36225 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 41
#  Time: 36450 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 41
#  Time: 36675 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 36900 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 37125 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 37350 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 37575 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 37800 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 38025 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 38250 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 42
#  Time: 38475 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 44
#  Time: 38700 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 44
#  Time: 38925 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 45
#  Time: 39150 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 45
#  Time: 39375 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 45
#  Time: 39600 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 39825 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 40050 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 40275 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 40500 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 40725 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 40950 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 41175 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 41400 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 41625 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 46
#  Time: 41850 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 47
#  Time: 42075 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 47
#  Time: 42300 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 47
#  Time: 42525 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 47
#  Time: 42750 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 47
#  Time: 42975 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 47
#  Time: 43200 minutes
